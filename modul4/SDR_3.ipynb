# %% [markdown]
# # Modulacja AM

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %% [markdown]
# ## Przykładowy sygnał

# %%
dt = 1e-6
T = 1e-3
N = int(T/dt)
Nfft = N*10

n = np.arange(N)
t = n*dt

s = np.exp(-0.5*(t-T/2)**2/(0.1*T)**2)
S = np.fft.fftshift(np.fft.fft(s, Nfft))/N

f = (np.arange(Nfft) - Nfft/2)/Nfft/dt

plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(t*1e3, s)
plt.xlabel('t [ms]')
plt.grid('on')

plt.subplot(122)
plt.plot(f*1e-3, 20*np.log(np.abs(S)))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-100, 100])
# Out:
# (-100.0, 100.0)

# %% [markdown]
# ## Modulacja amplitudy

# %%
fc = 20e3
c = np.cos(2*np.pi*fc * t)

m = s*c
M = np.fft.fftshift(np.fft.fft(m, Nfft))/N


plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(t*1e3, m)
plt.xlabel('t [ms]')
plt.grid('on')

plt.subplot(122)
plt.plot(f*1e-3, 20*np.log(np.abs(M)))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-100, 100])
# Out:
# (-100.0, 100.0)

# %% [markdown]
# ## Projekt filtru dolnoprzepustowego

# %%
fs = 1/dt
f0 = 20e3
order = 128


a = scipy.signal.firwin(order, f0, fs=fs)
A = np.fft.fftshift(np.fft.fft(a, Nfft))

plt.subplot(122)
plt.plot(f*1e-3, 20*np.log(np.abs(A)))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-100, 100])
plt.ylim([-60, 20])
# Out:
# (-60.0, 20.0)

# %% [markdown]
# ## Przemiana częstotliwości

# %%
# Przemiana częstotliwości (mieszacz)
m1_1 = m * np.cos(2*np.pi*fc*t)
M1_1 = np.fft.fftshift(np.fft.fft(m1_1, Nfft))/N

# Filtracja dolnoprzepustową
m1_2 = scipy.signal.convolve(m1_1, a, mode='same')
M1_2 = np.fft.fftshift(np.fft.fft(m1_2, Nfft))/N

plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(t*1e3, m1_1, t*1e3, m1_2)
plt.xlabel('t [ms]')
plt.grid('on')

plt.subplot(122)
plt.plot(f*1e-3, 20*np.log(np.abs(M1_1)), f*1e-3, 20*np.log(np.abs(M1_2)))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-100, 100])
# Out:
# (-100.0, 100.0)

# %% [markdown]
# ## Przesunięcie fazy

# %%
phi = 90*np.pi/180

# Przemiana częstotliwości (mieszacz)
m2_1i = m * np.cos(2*np.pi*fc*t + phi)
M2_1i = np.fft.fftshift(np.fft.fft(m2_1i, Nfft))/N

m2_1q = m * np.sin(2*np.pi*fc*t + phi)
M2_1q = np.fft.fftshift(np.fft.fft(m2_1q, Nfft))/N


# Filtracja dolnoprzepustową
m2_2i = scipy.signal.convolve(m2_1i, a, mode='same')
M2_2i = np.fft.fftshift(np.fft.fft(m2_2i, Nfft))/N

m2_2q = scipy.signal.convolve(m2_1q, a, mode='same')
M2_2q = np.fft.fftshift(np.fft.fft(m2_2q, Nfft))/N

# Odtworzenie sygnału
m2_3 = np.sqrt(m2_2i**2 + m2_2q**2)

cphi_ = m2_2i/m2_3
sphi_ = m2_2q/m2_3

#m2_4 = m2_2i*np.cos(phi) + m2_2q*np.sin(phi)
m2_4 = m2_2i*cphi_ + m2_2q*sphi_

plt.figure(figsize=(12,4))

plt.subplot(221)
plt.plot(t*1e3, m2_2i, t*1e3, m2_2q)
plt.xlabel('t [ms]')
plt.grid('on')
plt.legend(('s_i', 's_q'))

plt.subplot(222)
plt.plot(f*1e-3, 20*np.log(np.abs(M2_1i)), f*1e-3, 20*np.log(np.abs(M2_2i)))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-100, 100])

plt.subplot(223)
plt.plot(t*1e3, m2_3)
plt.xlabel('t [ms]')
plt.grid('on')

# %% [markdown]
# ## Operacje na liczbach zespolonych

# %%
phi = 90*np.pi/180

# Przemiana częstotliwości (mieszacz)
m2_1i = m * np.cos(2*np.pi*fc*t + phi)
m2_1q = m * np.sin(2*np.pi*fc*t + phi)
m2_1 = m2_1i + 1j*m2_1q

# Filtracja dolnoprzepustową
m2_2 = scipy.signal.convolve(m2_1, a, mode='same')

# Odtworzenie sygnału
m2_3 = np.abs(m2_2)
m2_4 = m2_2 * np.exp(-1j*phi)

plt.plot(t*1e3, m2_3, t*1e3, np.real(m2_4))
plt.xlabel('t [ms]')
plt.grid('on')

# %% [markdown]
# #Transformacja Hilberta

# %%
mh = scipy.signal.hilbert(m)

mi = np.real(mh)
mq = np.imag(mh)

Mi = np.fft.fftshift(np.fft.fft(mi, Nfft))/N
Mq = np.fft.fftshift(np.fft.fft(mq, Nfft))/N
Mh = np.fft.fftshift(np.fft.fft(mh, Nfft))/N

s_ = np.abs(mh)

plt.figure(figsize=(12,4))

plt.subplot(221)
plt.plot(t*1e3, mi)
plt.xlabel('t [ms]')
plt.grid('on')

plt.subplot(222)
plt.plot(f*1e-3, np.real(Mi), f*1e-3, np.imag(Mi))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-25, 25])

plt.subplot(223)
plt.plot(t*1e3, mq)
plt.xlabel('t [ms]')
plt.grid('on')

plt.subplot(224)
plt.plot(f*1e-3, np.real(1j*Mq), f*1e-3, np.imag(1j*Mq))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-25, 25])

plt.figure(figsize=(6,4))

plt.subplot(122)
plt.plot(f*1e-3, np.real(Mh), f*1e-3, np.imag(Mh))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-25, 25])

plt.subplot(121)
plt.plot(t*1e3, s_)
plt.xlabel('t [ms]')
plt.grid('on')

# %% [markdown]
# ## Demodulacja metodą podnoszenia do kwadratu

# %%
# Przemiana częstotliwości (mieszacz)
m1_1 = m * m
M1_1 = np.fft.fftshift(np.fft.fft(m1_1, Nfft))/N

# Filtracja dolnoprzepustową
m1_2 = scipy.signal.convolve(m1_1, a, mode='same')
M1_2 = np.fft.fftshift(np.fft.fft(m1_2, Nfft))/N

plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(t*1e3, m1_1, t*1e3, np.sqrt(2*m1_2), t*1e3, s)
plt.xlabel('t [ms]')
plt.grid('on')

plt.subplot(122)
plt.plot(f*1e-3, 20*np.log(np.abs(M1_1)), f*1e-3, 20*np.log(np.abs(M1_2)))
plt.xlabel('f [kHz]')
plt.grid('on')
plt.xlim([-100, 100])
# Out:
# (-100.0, 100.0)
